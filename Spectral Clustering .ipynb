# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler, normalize 
from sklearn.decomposition import PCA 
from sklearn.metrics import silhouette_score

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
X = dataset.iloc[:, 3:5].values
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import SpectralClustering 
clusmodel = SpectralClustering(n_clusters=10, eigen_solver='arpack', n_components=None, random_state=None, n_init=10, gamma=1.0, affinity='rbf', n_neighbors=10, eigen_tol='auto', assign_labels='discretize', degree=3, coef0=1, kernel_params=None, n_jobs=None, verbose=False)
label = clusmodel .fit_predict(X)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\_spectral_embedding.py:455: UserWarning: Exited at iteration 2000 with accuracies
# [5.03238858e-13 1.78041989e-07 1.16013259e-06 3.91052186e-07
#  4.18099110e-07 1.35252952e-06 6.38795928e-07 1.35937792e-06
#  1.20528400e-06 1.93633175e-06 2.05119751e-05]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 1995 instead with accuracy
# 1.4201870354763718e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\_spectral_embedding.py:455: UserWarning: Exited postprocessing with accuracies
# [1.06346562e-13 1.54122695e-07 9.32568624e-07 3.86465191e-07
#  4.15932739e-07 1.11363202e-06 6.36840105e-07 1.32130144e-06
#  1.11943734e-06 9.85764765e-07 8.55598262e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised=dataset

# %%
supervised['Cluster_group']=label

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                0
# 1                0
# 2                0
# ...

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5], 
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
#hue FOR colur 5 means how many colur
# hue=supervised.columns[5], color 
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5],
                   #legend_out=True = cluster group list show perpose
                   #show graf    
                   fit_reg=False,legend_out=True)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)
