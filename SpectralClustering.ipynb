# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#dataset: Your DataFrame.
#.iloc: The method for selecting data by integer index.
#[rows:, 3:5columns]: This slice selects all rows (:) and columns from index 3 (inclusive) up to 5 (exclusive).
#.values: Converts the selected subset to a NumPy array.
X = dataset.iloc[:, 3:5].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans
list1 = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    list1.append(kmeans.inertia_)
    #import matplotlib.pyplot as plt
#range automatic count
plt.plot(range(1, 11), list1)
#tittel
plt.title('The Elbow Method')
#xlabel
plt.xlabel('Number of clusters')
#inertia
plt.ylabel('WCSS')
#reuslt
plt.show()



#listcount tarket point (5)

# %%
list1
# Out:
# [269981.28,
#  183653.3289473684,
#  106348.37306211119,
#  73880.64496247195,
#  44448.45544793371,
#  40825.16946386946,
#  33642.579220779226,
#  26686.83778518778,
#  24766.471609793443,
#  23103.122085983916]

# %%
from sklearn.cluster import SpectralClustering 
SpectralClustering = SpectralClustering(n_clusters=8, eigen_solver=None, n_components=None, random_state=None, n_init=10, gamma=1.0, affinity='rbf', n_neighbors=10, eigen_tol='auto', assign_labels='kmeans', degree=3, coef0=1, kernel_params=None, n_jobs=None, verbose=False)
#model ctrat and prerite
label  = SpectralClustering.fit_predict(X)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\_spectral_embedding.py:455: UserWarning: Exited at iteration 2000 with accuracies
# [3.98453548e-14 3.35008719e-07 6.15322701e-07 3.92617199e-07
#  3.54535869e-07 9.82884202e-07 4.42995250e-06 3.42610148e-06
#  1.44312590e-05]
# not reaching the requested tolerance 2.9802322387695312e-06.
# Use iteration 1665 instead with accuracy
# 1.061371106287374e-06.
#
#   _, diffusion_map = lobpcg(
# C:\Anaconda3\envs\aiml\lib\site-packages\sklearn\manifold\_spectral_embedding.py:455: UserWarning: Exited postprocessing with accuracies
# [8.99475781e-15 2.86676333e-07 6.02604110e-07 3.92508174e-07
#  3.42150470e-07 7.65261861e-07 1.37268748e-06 1.46499452e-06
#  4.32545534e-06]
# not reaching the requested tolerance 2.9802322387695312e-06.
#   _, diffusion_map = lobpcg(
# ...

# %%
#Cluster_group categary splite

# %%
supervised=pd.DataFrame(dataset)
supervised=dataset

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
#=label create modele
##Cluster_group categary splite
supervised['Cluster_group']=label

# %%
#cluster_group 4= 2= 1= 3=
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0                0
# 1                0
# 2                0
# ...

# %%
#save csv
supervised.to_csv("cluster.csv",index=False)

# %%
centroids=kmeans.cluster_centers_

# %%
#kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
centroids
# Out:
# array([[ 56.46478873,  49.77464789],
#        [ 97.09090909,  86.09090909],
#        [ 79.        ,  16.59259259],
#        [ 23.42857143,  84.78571429],
#        [ 24.58333333,   9.58333333],
#        [ 76.96      ,  80.8       ],
#        [ 31.53333333,  35.86666667],
#        [109.7       ,  22.        ],
#        [ 33.5       ,  66.25      ],
#        [127.66666667,  78.66666667]])

# %%
supervised.columns[3]
# Out:
# 'Annual Income (k$)'

# %%
supervised.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)', 'Cluster_group'],
#       dtype='object')

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5], 
                   fit_reg=False, legend=True, legend_out=True)
# cheak x,y
#0-B incm 40-80 sped 40-60=%
#1-O incm 80-140 sped 60-100=%
#2-G inm 20-40 sped 60-100=%
#3-R incm 60-140 sped 0-40=%
#4-BE  incm 60-140 sped 0-40=
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
#hue FOR colur 5 means how many colur
# hue=supervised.columns[5], color 
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5],
                   #legend_out=True = cluster group list show perpose
                   #show graf    
                   fit_reg=False,legend_out=True)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
#!pip install seaborn

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
